# %% [markdown]
# Capítulo 6
#
# 6.2 Patrones de filtrado.
#
# 6.2.3 Filtro de valores no repetidos
#
# Filtro que a partir de un conjunto de valores repetidos, nos mostrará una lista con valores filtrados no repetidos. Eliminará los registros en base al dato del campo que le indiquemos. En este ejemplo eliminaremos los registros cuya dirección IP sea igual, ya que necesitamos un informe el usuario y las distintas direcciones IP desde las que se ha conectado.

# %%
# %config IPCompleter.greedy=True

# %%
# %%writefile valoresNoRepetidos.py
#!/usr/bin/env python

from mrjob.job import MRJob
import re

#Expresion regular para validar ip
ip = ('^(?:(?:25[0-5]|2[0-4][0-9]|'
          '[01]?[0-9][0-9]?)\.){3}'
          '(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)$')
IP_RE = re.compile(ip)

class valoresNoRepetidos(MRJob):
    
    def mapper(self,_, line):
        linea=line.split(";")
        encontrado=re.search(IP_RE,linea[5])
        if encontrado!=None:    
            yield _,linea
        
    def reducer(self, key, values):
        listaDef=[] #Lista para los registros únicos filtrados
        listaControl=[] #Lista para el control de los registros que son repetidos
        
        # metemos los valores en las listas con lo que nos viene del mapper.
        for valor in values:
            #Si el valor de control (en este caso la IP) no está en la lista de control
            #agregamos el valor de control en la lista de control, y el registro completo en la 
            #lista definitiva.
            if valor[5] not in listaControl:
                listaControl.append(valor[5])
                listaDef.append(valor)
                
        #Podemos sacar por el reducer lo que estimemos        
        for p in listaDef:
            yield p[1], (p[1],p[5])
            
if __name__ == '__main__':
    valoresNoRepetidos.run()
# Out:
# Overwriting valoresNoRepetidos.py

# %%
# !python valoresNoRepetidos.py archivos_datos/eventos_alumnos.csv
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory /tmp/valoresNoRepetidos.root.20201214.191832.669167
# Running step 1 of 1...
# job output is in /tmp/valoresNoRepetidos.root.20201214.191832.669167/output
# Streaming final output from /tmp/valoresNoRepetidos.root.20201214.191832.669167/output...
# "Alumna1"	["Alumna1", "217.125.48.43"]
# "Admin Manuel R."	["Admin Manuel R.", "87.221.75.73"]
# "Alumno5"	["Alumno5", "195.77.157.196"]
# "Alumna3"	["Alumna3", "37.222.51.156"]
# "Alumno6"	["Alumno6", "31.4.245.175"]
# "Alumno7"	["Alumno7", "87.223.30.0"]
# "Alumna8"	["Alumna8", "85.61.123.29"]
# "Profesor1"	["Profesor1", "80.39.209.6"]
# "Alumno21"	["Alumno21", "81.32.157.225"]
# "Alumno4"	["Alumno4", "150.214.205.80"]
# "Alumno23"	["Alumno23", "176.83.39.22"]
# "Alumno23"	["Alumno23", "80.31.142.47"]
# "Alumno21"	["Alumno21", "83.54.50.245"]
# "Tutor1"	["Tutor1", "212.145.201.139"]
# "Alumna25"	["Alumna25", "176.84.181.12"]
# "Alumno12"	["Alumno12", "85.137.125.12"]
# "Alumna10"	["Alumna10", "217.216.174.197"]
# "Alumno4"	["Alumno4", "159.147.36.152"]
# "Alumno11"	["Alumno11", "2.59.95.231"]
# "Alumna9"	["Alumna9", "86.127.232.121"]
# "Alumna10"	["Alumna10", "31.4.222.134"]
# "Alumno13"	["Alumno13", "77.226.115.25"]
# "Alumno5"	["Alumno5", "188.78.94.35"]
# "Profesor1"	["Profesor1", "150.214.205.52"]
# "Alumna18"	["Alumna18", "88.23.43.186"]
# "Alumno13"	["Alumno13", "144.2.165.119"]
# "Alumno19"	["Alumno19", "77.230.252.22"]
# "Alumno24"	["Alumno24", "217.216.197.215"]
# "Alumno2"	["Alumno2", "188.85.142.160"]
# "Profesor1"	["Profesor1", "150.214.205.47"]
# "Alumno14"	["Alumno14", "95.127.224.177"]
# "Alumno7"	["Alumno7", "87.223.31.104"]
# "Alumno20"	["Alumno20", "83.50.220.87"]
# "Alumno22"	["Alumno22", "144.2.164.195"]
# "Alumno4"	["Alumno4", "150.214.205.72"]
# "Alumna17"	["Alumna17", "46.6.6.162"]
# "Alumno23"	["Alumno23", "77.226.188.184"]
# "Alumno15"	["Alumno15", "37.11.55.170"]
# "Alumna8"	["Alumna8", "84.78.25.116"]
# "Alumno12"	["Alumno12", "150.214.205.75"]
# "Alumno20"	["Alumno20", "95.60.61.130"]
# "Alumno12"	["Alumno12", "31.4.219.140"]
# "Alumna10"	["Alumna10", "31.4.223.205"]
# "Alumno4"	["Alumno4", "95.61.232.186"]
# "Alumna9"	["Alumna9", "188.26.220.22"]
# "Alumna10"	["Alumna10", "150.214.205.156"]
# "Alumno4"	["Alumno4", "95.60.89.31"]
# "Alumno4"	["Alumno4", "95.60.86.91"]
# "Alumno4"	["Alumno4", "95.60.63.145"]
# "Alumno11"	["Alumno11", "2.59.92.211"]
# "Alumna8"	["Alumna8", "213.143.60.76"]
# "Alumno7"	["Alumno7", "95.18.16.95"]
# "Alumno20"	["Alumno20", "95.60.90.145"]
# "Alumno4"	["Alumno4", "148.3.124.172"]
# "Alumno6"	["Alumno6", "85.137.128.49"]
# "Alumno20"	["Alumno20", "95.60.61.81"]
# "Alumno4"	["Alumno4", "150.214.205.76"]
# "Alumno21"	["Alumno21", "37.130.146.225"]
# "Alumno6"	["Alumno6", "84.79.207.193"]
# "Alumno7"	["Alumno7", "87.223.25.247"]
# "Alumno22"	["Alumno22", "83.35.222.184"]
# "Alumno4"	["Alumno4", "159.147.245.47"]
# "Alumno23"	["Alumno23", "77.226.136.220"]
# "Alumna3"	["Alumna3", "150.214.205.151"]
# "Alumno20"	["Alumno20", "31.4.198.129"]
# "Alumno6"	["Alumno6", "85.49.193.224"]
# "Alumno4"	["Alumno4", "83.36.91.175"]
# "Alumno23"	["Alumno23", "79.147.101.8"]
# "Alumno20"	["Alumno20", "83.35.220.82"]
# "Alumno4"	["Alumno4", "95.60.99.15"]
# "Alumno24"	["Alumno24", "85.137.102.2"]
# "Alumna8"	["Alumna8", "84.78.26.200"]
# "Alumno7"	["Alumno7", "84.78.245.207"]
# "Alumno7"	["Alumno7", "185.197.90.35"]
# "Alumno4"	["Alumno4", "31.177.98.58"]
# "Alumno4"	["Alumno4", "31.177.98.18"]
# "Alumno4"	["Alumno4", "150.214.205.66"]
# "Alumno24"	["Alumno24", "217.216.195.41"]
# "Alumno20"	["Alumno20", "148.56.87.28"]
# "Alumno7"	["Alumno7", "87.223.18.84"]
# "Alumna25"	["Alumna25", "88.24.133.200"]
# "Alumno4"	["Alumno4", "150.214.205.64"]
# "Alumna3"	["Alumna3", "150.214.205.159"]
# "Alumno7"	["Alumno7", "87.223.25.127"]
# "Alumna3"	["Alumna3", "150.214.205.153"]
# "Alumno4"	["Alumno4", "95.60.99.192"]
# "Alumna25"	["Alumna25", "88.22.136.192"]
# "Alumno14"	["Alumno14", "37.11.147.249"]
# "Alumna9"	["Alumna9", "188.26.213.213"]
# "Alumno13"	["Alumno13", "83.35.221.116"]
# "Alumno20"	["Alumno20", "31.4.195.39"]
# "Alumno4"	["Alumno4", "150.214.205.56"]
# "Alumna10"	["Alumna10", "31.4.219.116"]
# "Alumno24"	["Alumno24", "85.137.100.62"]
# "Alumno20"	["Alumno20", "31.4.194.183"]
# "Alumno4"	["Alumno4", "87.125.227.5"]
# "Alumno20"	["Alumno20", "31.4.195.45"]
# "Alumno20"	["Alumno20", "148.56.163.170"]
# "Alumno16"	["Alumno16", "185.181.238.37"]
# "Alumno20"	["Alumno20", "83.50.223.98"]
# "Alumna8"	["Alumna8", "84.78.26.156"]
# "Admin Manuel R."	["Admin Manuel R.", "87.221.73.119"]
# "Alumno7"	["Alumno7", "95.18.16.115"]
# "Alumna10"	["Alumna10", "31.4.217.45"]
# "Alumna25"	["Alumna25", "176.84.178.24"]
# "Alumno24"	["Alumno24", "85.137.220.110"]
# "Alumno4"	["Alumno4", "150.214.205.81"]
# "Alumna18"	["Alumna18", "213.99.91.28"]
# "Alumno5"	["Alumno5", "37.35.149.235"]
# "Alumno24"	["Alumno24", "85.137.130.42"]
# "Alumno21"	["Alumno21", "176.83.23.124"]
# "Alumna9"	["Alumna9", "188.26.213.139"]
# "Alumno14"	["Alumno14", "213.99.95.135"]
# "Profesor1"	["Profesor1", "150.214.205.42"]
# "Alumno21"	["Alumno21", "212.170.76.26"]
# "Alumna25"	["Alumna25", "176.84.179.167"]
# "Alumno2"	["Alumno2", "83.58.5.4"]
# "Alumna8"	["Alumna8", "46.25.70.175"]
# "Profesor3"	["Profesor3", "81.38.133.38"]
# "Alumno4"	["Alumno4", "150.214.205.70"]
# "Alumno24"	["Alumno24", "85.137.220.175"]
# "Alumno24"	["Alumno24", "85.137.220.224"]
# "Alumno21"	["Alumno21", "95.127.48.86"]
# "Alumno20"	["Alumno20", "95.60.225.113"]
# "Alumno14"	["Alumno14", "176.83.53.184"]
# "Alumna25"	["Alumna25", "88.5.129.114"]
# "Alumno24"	["Alumno24", "85.137.100.87"]
# "Alumna25"	["Alumna25", "88.19.212.155"]
# "Alumna8"	["Alumna8", "95.63.176.198"]
# "Alumno4"	["Alumno4", "95.63.111.224"]
# "Alumno21"	["Alumno21", "81.34.177.154"]
# "Alumno7"	["Alumno7", "87.223.25.183"]
# "Alumno2"	["Alumno2", "88.12.88.214"]
# "Alumno4"	["Alumno4", "95.60.99.12"]
# "Alumno4"	["Alumno4", "95.61.251.149"]
# "Alumna8"	["Alumna8", "80.174.207.199"]
# "Alumno21"	["Alumno21", "193.152.33.126"]
# "Alumno21"	["Alumno21", "176.83.17.218"]
# "Profesor3"	["Profesor3", "150.214.205.162"]
# "Alumna8"	["Alumna8", "46.24.129.72"]
# "Alumno21"	["Alumno21", "83.54.53.99"]
# "Alumno4"	["Alumno4", "95.60.225.203"]
# "Alumno14"	["Alumno14", "95.127.254.193"]
# "Alumna8"	["Alumna8", "77.225.188.14"]
# "Alumna8"	["Alumna8", "95.63.177.71"]
# "Alumno7"	["Alumno7", "95.22.198.232"]
# "Alumno21"	["Alumno21", "83.54.49.54"]
# "Alumna8"	["Alumna8", "31.4.218.121"]
# "Alumna25"	["Alumna25", "88.22.136.46"]
# "Alumno20"	["Alumno20", "95.60.86.217"]
# "Alumno22"	["Alumno22", "83.50.218.90"]
# "Alumna3"	["Alumna3", "150.214.205.157"]
# "Alumna25"	["Alumna25", "95.127.226.125"]
# "Alumno5"	["Alumno5", "176.227.155.129"]
# "Alumna25"	["Alumna25", "176.84.182.213"]
# "Alumna25"	["Alumna25", "95.127.224.75"]
# "Alumno4"	["Alumno4", "95.61.253.139"]
# "Alumno7"	["Alumno7", "95.22.203.227"]
# "Alumno24"	["Alumno24", "217.216.197.171"]
# "Alumno21"	["Alumno21", "176.83.17.92"]
# "Alumno24"	["Alumno24", "31.4.196.110"]
# "Alumno14"	["Alumno14", "176.83.52.47"]
# "Alumno5"	["Alumno5", "31.4.159.0"]
# "Alumna25"	["Alumna25", "95.127.56.43"]
# "Alumno4"	["Alumno4", "95.60.98.152"]
# "Alumna17"	["Alumna17", "85.55.182.28"]
# "Alumna9"	["Alumna9", "188.26.215.18"]
# "Alumno23"	["Alumno23", "2.137.249.144"]
# "Alumno21"	["Alumno21", "81.36.80.235"]
# "Alumno21"	["Alumno21", "81.32.156.235"]
# "Alumno7"	["Alumno7", "95.22.238.16"]
# "Alumna9"	["Alumna9", "188.26.210.133"]
# "Alumna3"	["Alumna3", "150.214.205.154"]
# "Alumna18"	["Alumna18", "88.22.107.174"]
# "Alumna25"	["Alumna25", "176.84.177.2"]
# "Alumna25"	["Alumna25", "176.84.177.119"]
# "Alumno20"	["Alumno20", "89.7.140.93"]
# "Alumno4"	["Alumno4", "95.60.99.69"]
# "Alumna25"	["Alumna25", "95.127.243.232"]
# "Alumna25"	["Alumna25", "176.84.179.171"]
# "Alumna8"	["Alumna8", "137.101.56.74"]
# "Alumna9"	["Alumna9", "188.76.136.163"]
# "Alumna8"	["Alumna8", "81.60.160.253"]
# "Alumno21"	["Alumno21", "81.36.80.35"]
# "Alumno5"	["Alumno5", "31.4.141.44"]
# "Alumno4"	["Alumno4", "95.61.251.144"]
# "Alumno15"	["Alumno15", "79.152.249.241"]
# "Alumno21"	["Alumno21", "83.54.48.156"]
# "Alumno15"	["Alumno15", "37.29.190.217"]
# "Alumno7"	["Alumno7", "95.22.234.137"]
# "Alumno4"	["Alumno4", "95.60.99.190"]
# "Alumno15"	["Alumno15", "79.153.130.68"]
# "Alumno25"	["Alumno25", "139.47.16.5"]
# "Alumno21"	["Alumno21", "88.11.120.218"]
# "Alumno4"	["Alumno4", "95.60.225.142"]
# "Alumno15"	["Alumno15", "46.6.214.247"]
# "Alumno21"	["Alumno21", "81.34.177.201"]
# "Alumno21"	["Alumno21", "37.10.153.115"]
# "Alumno21"	["Alumno21", "83.54.54.51"]
# "Alumno25"	["Alumno25", "139.47.21.110"]
# "Alumno7"	["Alumno7", "95.22.192.183"]
# "Alumno5"	["Alumno5", "31.4.156.26"]
# "Alumno5"	["Alumno5", "31.4.129.44"]
# "Alumno5"	["Alumno5", "31.4.129.51"]
# "Alumna9"	["Alumna9", "46.6.240.141"]
# "Alumno12"	["Alumno12", "150.214.205.85"]
# "Alumno4"	["Alumno4", "89.7.140.24"]
# "Alumna25"	["Alumna25", "176.84.180.125"]
# "Alumno20"	["Alumno20", "95.60.63.100"]
# "Alumna18"	["Alumna18", "95.121.124.168"]
# "Alumno21"	["Alumno21", "37.10.140.234"]
# "Alumno15"	["Alumno15", "37.29.194.54"]
# "Alumno21"	["Alumno21", "95.127.56.108"]
# "Alumno21"	["Alumno21", "176.83.9.229"]
# "Alumno4"	["Alumno4", "83.36.89.188"]
# "Alumna18"	["Alumna18", "88.21.22.74"]
# "Alumno21"	["Alumno21", "37.10.153.208"]
# "Alumno21"	["Alumno21", "193.152.45.48"]
# "Alumno4"	["Alumno4", "31.4.157.41"]
# "Alumno25"	["Alumno25", "139.47.3.138"]
# "Alumno15"	["Alumno15", "79.154.144.110"]
# "Alumno22"	["Alumno22", "83.50.216.130"]
# "Alumno21"	["Alumno21", "193.152.32.21"]
# "Alumno15"	["Alumno15", "46.6.214.141"]
# "Alumna18"	["Alumna18", "88.23.240.144"]
# "Alumno4"	["Alumno4", "77.231.182.191"]
# "Alumno20"	["Alumno20", "77.231.120.200"]
# "Alumna9"	["Alumna9", "88.10.159.150"]
# Removing temp directory /tmp/valoresNoRepetidos.root.20201214.191832.669167...

# %% [markdown]
# EJECUCIÓN EN EL CLUSTER

# %%
! python valoresNoRepetidos.py hdfs:///archivos_datos/eventos_alumnos.csv -r hadoop --python-bin /opt/anaconda/bin/python
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for hadoop runner
# Looking for hadoop binary in /usr/lib/hadoop/bin...
# Found hadoop binary: /usr/lib/hadoop/bin/hadoop
# Using Hadoop version 2.6.0
# Looking for Hadoop streaming jar in /usr/lib/hadoop...
# Looking for Hadoop streaming jar in /usr/lib/hadoop-mapreduce...
# Found Hadoop streaming jar: /usr/lib/hadoop-mapreduce/hadoop-streaming.jar
# Creating temp directory /tmp/valoresNoRepetidos.root.20201214.191950.895103
# uploading working dir files to hdfs:///user/root/tmp/mrjob/valoresNoRepetidos.root.20201214.191950.895103/files/wd...
# Copying other local files to hdfs:///user/root/tmp/mrjob/valoresNoRepetidos.root.20201214.191950.895103/files/
# Running step 1 of 1...
#   packageJobJar: [] [/usr/lib/hadoop-mapreduce/hadoop-streaming-2.6.0-cdh5.15.1.jar] /tmp/streamjob7248641279192841825.jar tmpDir=null
#   Connecting to ResourceManager at yarnmaster/172.18.0.5:8032
#   Connecting to ResourceManager at yarnmaster/172.18.0.5:8032
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1607966861739_0015
#   Submitted application application_1607966861739_0015
#   The url to track the job: http://yarnmaster:8088/proxy/application_1607966861739_0015/
#   Running job: job_1607966861739_0015
#   Job job_1607966861739_0015 running in uber mode : false
#    map 0% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1607966861739_0015 completed successfully
#   Output directory: hdfs:///user/root/tmp/mrjob/valoresNoRepetidos.root.20201214.191950.895103/output
# Counters: 50
# 	File Input Format Counters
# 		Bytes Read=2466171
# 	File Output Format Counters
# 		Bytes Written=9144
# 	File System Counters
# 		FILE: Number of bytes read=2932291
# 		FILE: Number of bytes written=6309865
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=2466385
# 		HDFS: Number of bytes written=9144
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=9
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Data-local map tasks=1
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Rack-local map tasks=1
# 		Total megabyte-milliseconds taken by all map tasks=47611904
# 		Total megabyte-milliseconds taken by all reduce tasks=13248512
# 		Total time spent by all map tasks (ms)=46496
# 		Total time spent by all maps in occupied slots (ms)=46496
# 		Total time spent by all reduce tasks (ms)=12938
# 		Total time spent by all reduces in occupied slots (ms)=12938
# 		Total vcore-milliseconds taken by all map tasks=46496
# 		Total vcore-milliseconds taken by all reduce tasks=12938
# 	Map-Reduce Framework
# 		CPU time spent (ms)=7870
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=927
# 		Input split bytes=214
# 		Map input records=15496
# 		Map output bytes=2887297
# 		Map output materialized bytes=2932297
# 		Map output records=15495
# 		Merged Map outputs=2
# 		Physical memory (bytes) snapshot=729550848
# 		Reduce input groups=1
# 		Reduce input records=15495
# 		Reduce output records=228
# 		Reduce shuffle bytes=2932297
# 		Shuffled Maps =2
# 		Spilled Records=30990
# 		Total committed heap usage (bytes)=606601216
# 		Virtual memory (bytes) snapshot=7889334272
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# job output is in hdfs:///user/root/tmp/mrjob/valoresNoRepetidos.root.20201214.191950.895103/output
# Streaming final output from hdfs:///user/root/tmp/mrjob/valoresNoRepetidos.root.20201214.191950.895103/output...
# "Alumno11"	["Alumno11", "2.59.95.231"]
# "Alumna3"	["Alumna3", "37.222.51.156"]
# "Alumno21"	["Alumno21", "83.54.50.245"]
# "Alumno7"	["Alumno7", "95.18.16.115"]
# "Alumno4"	["Alumno4", "87.125.227.5"]
# "Admin Manuel R."	["Admin Manuel R.", "87.221.73.119"]
# "Alumna8"	["Alumna8", "85.61.123.29"]
# "Alumna17"	["Alumna17", "46.6.6.162"]
# "Alumna8"	["Alumna8", "84.78.26.156"]
# "Alumno23"	["Alumno23", "79.147.101.8"]
# "Alumno11"	["Alumno11", "2.59.92.211"]
# "Alumno7"	["Alumno7", "87.223.25.127"]
# "Alumno20"	["Alumno20", "148.56.163.170"]
# "Alumno20"	["Alumno20", "83.50.223.98"]
# "Alumno16"	["Alumno16", "185.181.238.37"]
# "Alumno14"	["Alumno14", "37.11.147.249"]
# "Alumno12"	["Alumno12", "85.137.125.12"]
# "Alumna25"	["Alumna25", "88.24.133.200"]
# "Alumno6"	["Alumno6", "84.79.207.193"]
# "Alumno22"	["Alumno22", "83.35.222.184"]
# "Alumno20"	["Alumno20", "31.4.195.45"]
# "Admin Manuel R."	["Admin Manuel R.", "195.77.157.196"]
# "Alumna25"	["Alumna25", "88.22.136.192"]
# "Alumno24"	["Alumno24", "85.137.100.62"]
# "Alumno6"	["Alumno6", "85.137.128.49"]
# "Alumno20"	["Alumno20", "31.4.194.183"]
# "Alumna10"	["Alumna10", "31.4.219.116"]
# "Alumno2"	["Alumno2", "188.85.142.160"]
# "Alumno4"	["Alumno4", "150.214.205.56"]
# "Alumna3"	["Alumna3", "150.214.205.156"]
# "Alumno19"	["Alumno19", "77.230.252.22"]
# "Alumno20"	["Alumno20", "31.4.195.39"]
# "Alumno13"	["Alumno13", "83.35.221.116"]
# "Alumna9"	["Alumna9", "188.26.213.213"]
# "Alumno20"	["Alumno20", "148.56.87.28"]
# "Alumno13"	["Alumno13", "77.226.115.25"]
# "Alumna3"	["Alumna3", "150.214.205.153"]
# "Alumna3"	["Alumna3", "150.214.205.151"]
# "Alumna1"	["Alumna1", "217.125.48.43"]
# "Alumna18"	["Alumna18", "88.23.43.186"]
# "Alumno4"	["Alumno4", "95.60.99.192"]
# "Alumno5"	["Alumno5", "188.78.94.35"]
# "Alumna25"	["Alumna25", "176.84.181.12"]
# "Alumna3"	["Alumna3", "150.214.205.159"]
# "Alumno4"	["Alumno4", "150.214.205.64"]
# "Alumno7"	["Alumno7", "87.223.18.84"]
# "Alumno24"	["Alumno24", "217.216.195.41"]
# "Alumno4"	["Alumno4", "150.214.205.66"]
# "Alumno7"	["Alumno7", "185.197.90.35"]
# "Alumno4"	["Alumno4", "31.177.98.18"]
# "Alumno4"	["Alumno4", "31.177.98.58"]
# "Alumno7"	["Alumno7", "84.78.245.207"]
# "Alumno4"	["Alumno4", "95.60.99.15"]
# "Alumna8"	["Alumna8", "84.78.26.200"]
# "Alumno24"	["Alumno24", "85.137.102.2"]
# "Alumna10"	["Alumna10", "217.216.174.197"]
# "Alumno20"	["Alumno20", "83.35.220.82"]
# "Alumna9"	["Alumna9", "188.26.220.22"]
# "Alumno15"	["Alumno15", "37.11.55.170"]
# "Alumno4"	["Alumno4", "83.36.91.175"]
# "Alumno23"	["Alumno23", "77.226.188.184"]
# "Alumno6"	["Alumno6", "85.49.193.224"]
# "Alumno20"	["Alumno20", "31.4.198.129"]
# "Alumno23"	["Alumno23", "77.226.136.220"]
# "Alumno4"	["Alumno4", "159.147.245.47"]
# "Alumno20"	["Alumno20", "95.60.61.81"]
# "Alumno21"	["Alumno21", "37.130.146.225"]
# "Alumno7"	["Alumno7", "87.223.25.247"]
# "Alumno4"	["Alumno4", "150.214.205.76"]
# "Alumno4"	["Alumno4", "148.3.124.172"]
# "Alumno7"	["Alumno7", "95.18.16.95"]
# "Alumno20"	["Alumno20", "95.60.90.145"]
# "Alumna10"	["Alumna10", "31.4.223.205"]
# "Alumna8"	["Alumna8", "213.143.60.76"]
# "Alumno4"	["Alumno4", "95.60.63.145"]
# "Alumno4"	["Alumno4", "95.60.86.91"]
# "Alumno4"	["Alumno4", "95.60.89.31"]
# "Alumno4"	["Alumno4", "95.61.232.186"]
# "Alumno20"	["Alumno20", "95.60.61.130"]
# "Alumno12"	["Alumno12", "31.4.219.140"]
# "Alumno7"	["Alumno7", "87.223.31.104"]
# "Alumno4"	["Alumno4", "150.214.205.72"]
# "Alumno12"	["Alumno12", "150.214.205.75"]
# "Alumno24"	["Alumno24", "217.216.197.215"]
# "Alumna8"	["Alumna8", "84.78.25.116"]
# "Alumno6"	["Alumno6", "144.2.164.195"]
# "Alumno20"	["Alumno20", "83.50.220.87"]
# "Alumno7"	["Alumno7", "87.223.30.0"]
# "Alumno14"	["Alumno14", "95.127.224.177"]
# "Profesor1"	["Profesor1", "150.214.205.47"]
# "Alumno4"	["Alumno4", "159.147.36.152"]
# "Alumno13"	["Alumno13", "144.2.165.119"]
# "Profesor1"	["Profesor1", "150.214.205.52"]
# "Alumna10"	["Alumna10", "31.4.222.134"]
# "Alumna9"	["Alumna9", "86.127.232.121"]
# "Tutor1"	["Tutor1", "212.145.201.139"]
# "Profesor1"	["Profesor1", "80.39.209.6"]
# "Alumno23"	["Alumno23", "80.31.142.47"]
# "Alumno23"	["Alumno23", "176.83.39.22"]
# "Alumno4"	["Alumno4", "150.214.205.80"]
# "Alumno21"	["Alumno21", "81.32.157.225"]
# "Alumno6"	["Alumno6", "31.4.245.175"]
# "Admin Manuel R."	["Admin Manuel R.", "87.221.75.73"]
# "Alumna9"	["Alumna9", "88.10.159.150"]
# "Alumno7"	["Alumno7", "217.216.197.171"]
# "Alumno21"	["Alumno21", "83.54.54.51"]
# "Alumno20"	["Alumno20", "77.231.120.200"]
# "Alumno4"	["Alumno4", "77.231.182.191"]
# "Alumna18"	["Alumna18", "88.23.240.144"]
# "Alumno15"	["Alumno15", "46.6.214.141"]
# "Alumno5"	["Alumno5", "176.227.155.129"]
# "Alumno21"	["Alumno21", "193.152.32.21"]
# "Alumno22"	["Alumno22", "83.50.216.130"]
# "Alumno15"	["Alumno15", "79.154.144.110"]
# "Alumno25"	["Alumno25", "139.47.3.138"]
# "Alumno4"	["Alumno4", "31.4.157.41"]
# "Alumno21"	["Alumno21", "193.152.45.48"]
# "Alumno21"	["Alumno21", "37.10.153.208"]
# "Alumna18"	["Alumna18", "88.21.22.74"]
# "Alumno4"	["Alumno4", "83.36.89.188"]
# "Alumno7"	["Alumno7", "95.22.192.183"]
# "Alumno21"	["Alumno21", "176.83.9.229"]
# "Alumno21"	["Alumno21", "95.127.56.108"]
# "Alumno15"	["Alumno15", "37.29.194.54"]
# "Alumno21"	["Alumno21", "37.10.140.234"]
# "Alumna18"	["Alumna18", "95.121.124.168"]
# "Alumno20"	["Alumno20", "95.60.63.100"]
# "Alumna25"	["Alumna25", "176.84.180.125"]
# "Alumno4"	["Alumno4", "89.7.140.24"]
# "Alumno12"	["Alumno12", "150.214.205.85"]
# "Alumna9"	["Alumna9", "46.6.240.141"]
# "Alumno25"	["Alumno25", "139.47.21.110"]
# "Alumno5"	["Alumno5", "31.4.129.51"]
# "Alumno5"	["Alumno5", "31.4.129.44"]
# "Alumna9"	["Alumna9", "188.76.136.163"]
# "Alumno5"	["Alumno5", "31.4.156.26"]
# "Alumno21"	["Alumno21", "37.10.153.115"]
# "Alumno2"	["Alumno2", "88.12.88.214"]
# "Alumno21"	["Alumno21", "81.34.177.201"]
# "Alumno4"	["Alumno4", "95.60.225.142"]
# "Alumno15"	["Alumno15", "46.6.214.247"]
# "Alumno21"	["Alumno21", "88.11.120.218"]
# "Alumno25"	["Alumno25", "139.47.16.5"]
# "Alumno21"	["Alumno21", "81.36.80.35"]
# "Alumno22"	["Alumno22", "83.50.218.90"]
# "Alumno4"	["Alumno4", "95.60.99.190"]
# "Alumna25"	["Alumna25", "88.22.136.46"]
# "Alumno15"	["Alumno15", "79.153.130.68"]
# "Alumna8"	["Alumna8", "81.60.160.253"]
# "Alumno4"	["Alumno4", "95.61.251.144"]
# "Alumno7"	["Alumno7", "95.22.234.137"]
# "Alumno15"	["Alumno15", "37.29.190.217"]
# "Alumno21"	["Alumno21", "83.54.48.156"]
# "Alumno15"	["Alumno15", "79.152.249.241"]
# "Alumno5"	["Alumno5", "31.4.141.44"]
# "Alumna8"	["Alumna8", "137.101.56.74"]
# "Alumna25"	["Alumna25", "176.84.179.171"]
# "Alumna25"	["Alumna25", "95.127.243.232"]
# "Alumna8"	["Alumna8", "95.63.177.71"]
# "Alumno4"	["Alumno4", "95.60.99.69"]
# "Alumno20"	["Alumno20", "89.7.140.93"]
# "Alumno20"	["Alumno20", "95.60.86.217"]
# "Alumna9"	["Alumna9", "188.26.210.133"]
# "Alumna25"	["Alumna25", "176.84.177.119"]
# "Alumna25"	["Alumna25", "176.84.177.2"]
# "Alumna3"	["Alumna3", "150.214.205.154"]
# "Alumna18"	["Alumna18", "88.22.107.174"]
# "Profesor3"	["Profesor3", "81.38.133.38"]
# "Alumno21"	["Alumno21", "81.32.156.235"]
# "Alumno7"	["Alumno7", "95.22.238.16"]
# "Alumno21"	["Alumno21", "81.36.80.235"]
# "Alumno23"	["Alumno23", "2.137.249.144"]
# "Alumna17"	["Alumna17", "85.55.182.28"]
# "Alumna9"	["Alumna9", "188.26.215.18"]
# "Alumno4"	["Alumno4", "95.60.98.152"]
# "Alumno14"	["Alumno14", "213.99.95.135"]
# "Alumna25"	["Alumna25", "95.127.56.43"]
# "Alumno5"	["Alumno5", "31.4.159.0"]
# "Alumno4"	["Alumno4", "95.61.253.139"]
# "Alumno14"	["Alumno14", "176.83.52.47"]
# "Alumno24"	["Alumno24", "31.4.196.110"]
# "Alumno21"	["Alumno21", "176.83.17.92"]
# "Alumno7"	["Alumno7", "95.22.203.227"]
# "Alumna25"	["Alumna25", "95.127.224.75"]
# "Alumno21"	["Alumno21", "83.54.49.54"]
# "Alumna25"	["Alumna25", "176.84.182.213"]
# "Alumna3"	["Alumna3", "150.214.205.157"]
# "Alumna25"	["Alumna25", "95.127.226.125"]
# "Alumna8"	["Alumna8", "31.4.218.121"]
# "Alumno7"	["Alumno7", "95.22.198.232"]
# "Alumno14"	["Alumno14", "95.127.254.193"]
# "Alumna8"	["Alumna8", "77.225.188.14"]
# "Alumno4"	["Alumno4", "95.60.225.203"]
# "Alumno21"	["Alumno21", "83.54.53.99"]
# "Alumna8"	["Alumna8", "46.24.129.72"]
# "Profesor3"	["Profesor3", "150.214.205.162"]
# "Alumno21"	["Alumno21", "81.34.177.154"]
# "Alumno21"	["Alumno21", "176.83.17.218"]
# "Alumno21"	["Alumno21", "193.152.33.126"]
# "Alumna8"	["Alumna8", "80.174.207.199"]
# "Alumno7"	["Alumno7", "87.223.25.183"]
# "Alumno4"	["Alumno4", "95.61.251.149"]
# "Alumno4"	["Alumno4", "95.60.99.12"]
# "Alumno4"	["Alumno4", "95.63.111.224"]
# "Alumna25"	["Alumna25", "176.84.179.167"]
# "Alumna8"	["Alumna8", "95.63.176.198"]
# "Alumna25"	["Alumna25", "88.19.212.155"]
# "Alumna8"	["Alumna8", "46.25.70.175"]
# "Alumna25"	["Alumna25", "88.5.129.114"]
# "Alumno5"	["Alumno5", "37.35.149.235"]
# "Alumno24"	["Alumno24", "85.137.100.87"]
# "Alumno14"	["Alumno14", "176.83.53.184"]
# "Alumno20"	["Alumno20", "95.60.225.113"]
# "Alumno21"	["Alumno21", "95.127.48.86"]
# "Alumno24"	["Alumno24", "85.137.220.224"]
# "Alumno24"	["Alumno24", "85.137.220.175"]
# "Alumno4"	["Alumno4", "150.214.205.70"]
# "Alumno2"	["Alumno2", "83.58.5.4"]
# "Alumno21"	["Alumno21", "212.170.76.26"]
# "Profesor1"	["Profesor1", "150.214.205.42"]
# "Alumna9"	["Alumna9", "188.26.213.139"]
# "Alumno21"	["Alumno21", "176.83.23.124"]
# "Alumno24"	["Alumno24", "85.137.130.42"]
# "Alumno4"	["Alumno4", "150.214.205.81"]
# "Alumno24"	["Alumno24", "85.137.220.110"]
# "Alumna18"	["Alumna18", "213.99.91.28"]
# "Alumna25"	["Alumna25", "176.84.178.24"]
# "Alumna10"	["Alumna10", "31.4.217.45"]
# Removing HDFS temp directory hdfs:///user/root/tmp/mrjob/valoresNoRepetidos.root.20201214.191950.895103...
# Removing temp directory /tmp/valoresNoRepetidos.root.20201214.191950.895103...
