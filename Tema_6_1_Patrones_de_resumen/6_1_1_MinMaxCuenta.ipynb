# %% [markdown]
# Capítulo 6
#
# 6.1 Patrones de resumen.
#
# 6.1.1 Resúmenes numéricos
#
# Patrón para extraer el valor máximo y el valor mínimo de un conjunto de valores. En este ejemplo usamos un tabla con clientes que han comporado en distintas fechas; filtrará  el valor más alto y más bajo de un cliente y el imoprte total de número de compras realizadas. Este patrón podríamos englobarlo dentro de los patrones de filtrado.

# %%
# %config IPCompleter.greedy=True

# %%
# %%writefile minmaxcount.py
#!/usr/bin/env python

from mrjob.job import MRJob
import re

class minmaxcount(MRJob):
    
    def mapper(self, _, line):
       
        linea=line.split(";")
        encontrado=re.search('^[0-9]',linea[5]) 
        
        if encontrado!=None:
            valor=linea[5] 
            clave=linea[6] 
            yield clave,float(valor)
        
    def reducer(self, key, values):
        #Lista donde almacenaremos los valores
        valores=[]
        
        #Recorremos la lista de "values"
        #para agregarlos a la lista
        for value in values:
            valores.append(value)
        
        #Ordenamos los valores de la lista
        valores.sort()
        #Valor máximo
        vMax=valores[len(valores)-1] 
        #Valor mínimo
        vMin=valores[0]
        #Número de valores del grupo
        cuenta=len(valores)
        
        yield key, (cuenta,vMax,vMin)
                
if __name__ == '__main__':
    minmaxcount.run()
# Out:
# Writing minmaxcount.py

# %%
# !python minmaxcount.py archivos_datos/Online_Retail.csv
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory /tmp/minmaxcount.root.20201214.182101.644041
# Running step 1 of 1...
# job output is in /tmp/minmaxcount.root.20201214.182101.644041/output
# Streaming final output from /tmp/minmaxcount.root.20201214.182101.644041/output...
# "14647"	[30, 4.95, 0.55]
# "14649"	[199, 14.95, 0.09]
# "14651"	[102, 16.95, 0.12]
# "14652"	[29, 9.95, 0.39]
# "14653"	[237, 12.75, 0.19]
# "14655"	[50, 14.95, 0.65]
# "14656"	[80, 12.75, 0.19]
# "14657"	[127, 14.95, 0.42]
# "14658"	[29, 39.95, 0.39]
# "14659"	[259, 12.75, 0.29]
# "14660"	[30, 12.5, 0.12]
# "14661"	[4, 11.15, 0.85]
# "14662"	[168, 9.95, 0.21]
# "14664"	[99, 9.95, 0.29]
# "14665"	[117, 16.95, 0.83]
# "14666"	[14, 9.95, 0.12]
# "14667"	[576, 19.95, 0.19]
# "14669"	[170, 16.95, 0.12]
# "14670"	[132, 7.95, 0.21]
# "14672"	[61, 12.75, 0.19]
# "14673"	[74, 4.95, 0.29]
# "14675"	[102, 12.75, 0.21]
# "14676"	[44, 8.5, 0.29]
# ...

# %% [markdown]
# EJECUCIÓN EN EL CLUSTER:

# %%
! python minmaxcount.py hdfs:///archivos_datos/Online_Retail.csv -r hadoop --python-bin /opt/anaconda/bin/python3.7
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for hadoop runner
# Looking for hadoop binary in /usr/lib/hadoop/bin...
# Found hadoop binary: /usr/lib/hadoop/bin/hadoop
# Using Hadoop version 2.6.0
# Looking for Hadoop streaming jar in /usr/lib/hadoop...
# Looking for Hadoop streaming jar in /usr/lib/hadoop-mapreduce...
# Found Hadoop streaming jar: /usr/lib/hadoop-mapreduce/hadoop-streaming.jar
# Creating temp directory /tmp/minmaxcount.root.20201214.182218.842294
# uploading working dir files to hdfs:///user/root/tmp/mrjob/minmaxcount.root.20201214.182218.842294/files/wd...
# Copying other local files to hdfs:///user/root/tmp/mrjob/minmaxcount.root.20201214.182218.842294/files/
# Running step 1 of 1...
#   packageJobJar: [] [/usr/lib/hadoop-mapreduce/hadoop-streaming-2.6.0-cdh5.15.1.jar] /tmp/streamjob832422854194220570.jar tmpDir=null
#   Connecting to ResourceManager at yarnmaster/172.18.0.5:8032
# ...

# %% [markdown]
# Capítulo 6
#
# 6.1 Patrones de resumen.
#
# 6.1.1 Resúmenes numéricos
#
# Segunda versión del patrón que calcula la cuenta, valor máximo y valor mínimo. La diferencia con la primera versión es que aquí usamos el método list, para asignar la lista de valores, en el Reducer. No usamos una estructura iterativa.

# %%
# %%writefile minmaxcountV2.py
#!/usr/bin/env python

from mrjob.job import MRJob
import re

class minmaxcountV2(MRJob):
    
    def mapper(self, _, line):
       
        linea=line.split(";")
        encontrado=re.search('^[0-9]',linea[5]) 
        if encontrado!=None:
            valor=linea[5] 
            clave=linea[6] 
            yield clave,float(valor)
    
    def reducer(self, key, values):
        valores=list(values)
        
        valores.sort()
        vMax=valores[len(valores)-1]
        vMin=valores[0]
        cuenta=len(valores)
        
        yield key, (cuenta,vMax,vMin)
        
if __name__ == '__main__':
    minmaxcountV2.run()
# Out:
# Overwriting minmaxcountV2.py

# %%
# !python minmaxcountV2.py archivos_datos/Online_Retail.csv
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory /tmp/minmaxcountV2.root.20201214.181328.178191
# Running step 1 of 1...
# job output is in /tmp/minmaxcountV2.root.20201214.181328.178191/output
# Streaming final output from /tmp/minmaxcountV2.root.20201214.181328.178191/output...
# "14647"	[30, 4.95, 0.55]
# "14649"	[199, 14.95, 0.09]
# "14651"	[102, 16.95, 0.12]
# "14652"	[29, 9.95, 0.39]
# "14653"	[237, 12.75, 0.19]
# "14655"	[50, 14.95, 0.65]
# "14656"	[80, 12.75, 0.19]
# "14657"	[127, 14.95, 0.42]
# "14658"	[29, 39.95, 0.39]
# "14659"	[259, 12.75, 0.29]
# "14660"	[30, 12.5, 0.12]
# "14661"	[4, 11.15, 0.85]
# "14662"	[168, 9.95, 0.21]
# "14664"	[99, 9.95, 0.29]
# "14665"	[117, 16.95, 0.83]
# "14666"	[14, 9.95, 0.12]
# "14667"	[576, 19.95, 0.19]
# "14669"	[170, 16.95, 0.12]
# "14670"	[132, 7.95, 0.21]
# "14672"	[61, 12.75, 0.19]
# "14673"	[74, 4.95, 0.29]
# "14675"	[102, 12.75, 0.21]
# "14676"	[44, 8.5, 0.29]
# ...

# %% [markdown]
# EJECUCIÓN EN EL CLUSTER:

# %%
! python minmaxcountV2.py hdfs:///archivos_datos/Online_Retail.csv -r hadoop --python-bin /opt/anaconda/bin/python3.7
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for hadoop runner
# Looking for hadoop binary in /usr/lib/hadoop/bin...
# Found hadoop binary: /usr/lib/hadoop/bin/hadoop
# Using Hadoop version 2.6.0
# Looking for Hadoop streaming jar in /usr/lib/hadoop...
# Looking for Hadoop streaming jar in /usr/lib/hadoop-mapreduce...
# Found Hadoop streaming jar: /usr/lib/hadoop-mapreduce/hadoop-streaming.jar
# Creating temp directory /tmp/minmaxcountV2.root.20201214.181508.985829
# uploading working dir files to hdfs:///user/root/tmp/mrjob/minmaxcountV2.root.20201214.181508.985829/files/wd...
# Copying other local files to hdfs:///user/root/tmp/mrjob/minmaxcountV2.root.20201214.181508.985829/files/
# Running step 1 of 1...
#   packageJobJar: [] [/usr/lib/hadoop-mapreduce/hadoop-streaming-2.6.0-cdh5.15.1.jar] /tmp/streamjob3341227839623400337.jar tmpDir=null
#   Connecting to ResourceManager at yarnmaster/172.18.0.5:8032
# ...
